# %% [markdown]
# <a href="https://colab.research.google.com/github/prasantapy/Notes-snapshots-/blob/main/Mcq's_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Questions 1
x = [1, 2, 3]
y = x
y.append(4)
print(x)

# %% [markdown]
# Here id of x and  id y is same .<br>
# if we modify or add related list .it's also effect another .<br>
# so my ans  [1,2,3,4]<br>

# %%
x = ([10,20,30],[10,20])
x[0][0] = 999
print(x)
print(type(x))

# %%
def f(a=[]):
    a.append(1)
    return a

print(f())
print(f())

# %%
print(None == False or True)
print(None is None)

# %%
class Test:
  x = 10
a = Test()
b =Test()
x= 20
print('Hello ')
print(Test.x,a.x,b.x)

# %%
class A:
  def __init__(self):
    self.x = 10
class B(A):
  def __init__(self):
    super().__init__()
    self.y = 20

obj = B()
print(obj.x)

# %%
class Test:
    def __init__(self):
        self.x = 5

obj = Test()
print(obj.x)
del obj.x
print(obj.x)

# %%
class A:
    value = 10

obj = A()

A.value = 50

print(obj.value)

# %%
class Test:
    def __init__(self):
        self.x = []

a = Test()
b = Test()

a.x.append(1)

print(b.x)

# %%
class Test:
  def __init__(self):
    self.name = ''

obj1 = Test()
obj2 = Test()

obj1.name='iteshree'
print(obj2.name)
print(obj1.name)

# %%
class A:
    def show(self):
        print("A")

class B(A):
  pass

class C(B):
    def show(self):
        super().show()
        print("C")

obj = C()
obj.show()

# %%
class A:
    pass

class B(A):
    pass

print(isinstance(B(), A))

# %%
class A:
    pass

class B(A):
    pass

print(issubclass(A, B))

# %%
class Test:
    def __private(self):
        print("Hello")



obj = Test()
print(obj._Test__private())

# %%
class A:
    x = 10

class B(A):
    x = 20

obj = B()

print(super(B, obj).x)

# %%
class A:
  pass
class B(A):
  pass
class C(B):
  pass

print(C.mro())

# %%
class A:
    x = 5

class B(A):
    pass

obj = B()

obj.x = 20

del obj.x

print(obj.x)




class Test:
    def __init__(self):
        self.x = 5

obj = Test()
print(obj.x)
del obj.x
print(obj.x)

# %%
x = 10

def fun():
    x = 20

fun()
print(x)

# %%
nums = [1,2,3,4,5]

print(list(filter(lambda x: x%2, nums)))

# %%
nums = [1,2,3]

m = map(lambda x:x*2, nums)
print(list(m))
print(list(m))

# print(list(m))
# print(list(m))

# %%
funcs = []

for i in range(3):
    funcs.append(lambda: i) #Lambda fucntions return only once

print([f() for f in funcs])

# %%
from functools import reduce

nums = [1,2,3,4]

print(reduce(lambda x,y:x-y, nums))

# %%
# """
#     *
#  * * *
# * * * * *
#  * * *
#    *

# """
st = 1
sp = 2

for i in range(3):
  print(' '*sp,'*'*st,sep='')
  st += 2
  sp -=1

st = 3
sp = 1
for i in range(2):
  print(' '*sp,'*'*st,sep='')
  st-=2
  sp+=1

# %%
"""
1 1 1 1
2 2 2
3 3
4

"""
count = 4

for x in range(1,5):
  print(str(x)*count,sep='')
  count -=1

# %%
for i in range(1,6):
  print(str(i)* i ,sep='')

# %%
n = 5

for i in range(1, n + 1):
    for j in range(i):
        print(chr(65 + j), end="")
    print()
